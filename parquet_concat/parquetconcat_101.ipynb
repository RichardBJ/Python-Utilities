# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

def merge_parquet_files(input_folder, output_folder, size_limit_mb=2, min_length_mb=1):
    Path(output_folder).mkdir(parents=True, exist_ok=True)

    current_df = None
    file_counter = 1
    current_size_mb = 0
    saved_files = []
    last_time = 0
    dt = None
    last_channel = None

    parquet_files = sorted([f for f in os.listdir(input_folder) if f.endswith('.parquet')])

    for file in parquet_files:
        file_path = os.path.join(input_folder, file)
        df = pd.read_parquet(file_path)

        # Ensure the Time and Channels columns exist
        if "Time" not in df.columns or "Channels" not in df.columns:
            raise ValueError(f"Time or Channels column not found in file {file}")

        # Calculate dt if not already set
        if dt is None:
            dt = round(df["Time"].diff().mean(), 3)
            print(f"Calculated dt: {dt}")

        # Find the correct joining point
        if last_channel is not None:
            joining_index = df.index[df['Channels'] == last_channel].tolist()
            if joining_index:
                joining_index = joining_index[0]
                print(f"Joining point found at index {joining_index} in file {file}")
                df = df.iloc[joining_index:]
            else:
                print(f"Warning: No matching Channels value found in file {file}")

        # Adjust time to be continuous
        if current_df is not None:
            time_shift = last_time + dt - df["Time"].iloc[0]
            df["Time"] += time_shift

        if current_df is None:
            current_df = df
        else:
            current_df = pd.concat([current_df, df], ignore_index=True)

        last_time = current_df["Time"].iloc[-1]
        last_channel = current_df["Channels"].iloc[-1]

        # Check the size of the current DataFrame
        current_size_mb = current_df.memory_usage(deep=True).sum() / 1024 / 1024

        # If size limit is reached, save the current DataFrame and start a new one
        if current_size_mb >= size_limit_mb:
            output_file = os.path.join(output_folder, f'merged_file_{file_counter}.parquet')
            current_df.to_parquet(output_file, index=False)
            print(f"Saved {output_file} (Size: {current_size_mb:.2f} MB)")
            
            saved_files.append((output_file, current_size_mb))
            
            # Reset for the next file, but keep the last row to ensure continuity
            current_df = current_df.iloc[[-1]]
            file_counter += 1
            current_size_mb = current_df.memory_usage(deep=True).sum() / 1024 / 1024

    # Handle the last file
    if current_df is not None:
        if current_size_mb < min_length_mb and len(saved_files) > 0:
            # Append to the penultimate file
            penultimate_file, penultimate_size = saved_files[-1]
            penultimate_df = pd.read_parquet(penultimate_file)
            merged_df = pd.concat([penultimate_df, current_df], ignore_index=True)
            merged_size_mb = merged_df.memory_usage(deep=True).sum() / 1024 / 1024
            
            merged_df.to_parquet(penultimate_file, index=False)
            print(f"Appended to {penultimate_file} (New size: {merged_size_mb:.2f} MB)")
        else:
            # Save as a new file
            output_file = os.path.join(output_folder, f'merged_file_{file_counter}.parquet')
            current_df.to_parquet(output_file, index=False)
            print(f"Saved {output_file} (Size: {current_size_mb:.2f} MB)")

    print("Merging complete!")

# Usage
input_folder = 'source'
output_folder = 'merged'
merge_parquet_files(input_folder, output_folder, size_limit_mb=10, min_length_mb=3)
# Out:
# Calculated dt: 0.1
# Joining point found at index 1332 in file regularSimv103OffyB_1.parquet
# Joining point found at index 715 in file regularSimv103OffyB_10.parquet
# Joining point found at index 1266 in file regularSimv103OffyB_11.parquet
# Joining point found at index 0 in file regularSimv103OffyB_12.parquet
# Joining point found at index 2240 in file regularSimv103OffyB_13.parquet
# Joining point found at index 1272 in file regularSimv103OffyB_14.parquet
# Joining point found at index 2910 in file regularSimv103OffyB_15.parquet
# Joining point found at index 2266 in file regularSimv103OffyB_16.parquet
# Joining point found at index 236 in file regularSimv103OffyB_17.parquet
# Joining point found at index 0 in file regularSimv103OffyB_18.parquet
# Joining point found at index 1699 in file regularSimv103OffyB_19.parquet
# Joining point found at index 3643 in file regularSimv103OffyB_2.parquet
# Joining point found at index 746 in file regularSimv103OffyB_20.parquet
# Joining point found at index 617 in file regularSimv103OffyB_21.parquet
# Joining point found at index 758 in file regularSimv103OffyB_22.parquet
# Joining point found at index 1484 in file regularSimv103OffyB_23.parquet
# Joining point found at index 344 in file regularSimv103OffyB_24.parquet
# Joining point found at index 664 in file regularSimv103OffyB_25.parquet
# Joining point found at index 2408 in file regularSimv103OffyB_26.parquet
# Joining point found at index 206 in file regularSimv103OffyB_27.parquet
# Joining point found at index 0 in file regularSimv103OffyB_28.parquet
# Joining point found at index 420 in file regularSimv103OffyB_29.parquet
# Joining point found at index 1013 in file regularSimv103OffyB_3.parquet
# Joining point found at index 197 in file regularSimv103OffyB_30.parquet
# Joining point found at index 184 in file regularSimv103OffyB_31.parquet
# Joining point found at index 1690 in file regularSimv103OffyB_32.parquet
# Joining point found at index 307 in file regularSimv103OffyB_33.parquet
# Joining point found at index 4351 in file regularSimv103OffyB_34.parquet
# Joining point found at index 4917 in file regularSimv103OffyB_35.parquet
# Joining point found at index 1571 in file regularSimv103OffyB_36.parquet
# Joining point found at index 791 in file regularSimv103OffyB_37.parquet
# Joining point found at index 1 in file regularSimv103OffyB_38.parquet
# Joining point found at index 2171 in file regularSimv103OffyB_39.parquet
# Joining point found at index 4221 in file regularSimv103OffyB_4.parquet
# Joining point found at index 830 in file regularSimv103OffyB_40.parquet
# Joining point found at index 0 in file regularSimv103OffyB_41.parquet
# Joining point found at index 0 in file regularSimv103OffyB_42.parquet
# Joining point found at index 3272 in file regularSimv103OffyB_43.parquet
# Joining point found at index 2409 in file regularSimv103OffyB_44.parquet
# Joining point found at index 736 in file regularSimv103OffyB_45.parquet
# Joining point found at index 960 in file regularSimv103OffyB_46.parquet
# Joining point found at index 3633 in file regularSimv103OffyB_47.parquet
# Joining point found at index 1173 in file regularSimv103OffyB_48.parquet
# Joining point found at index 662 in file regularSimv103OffyB_49.parquet
# Joining point found at index 1032 in file regularSimv103OffyB_5.parquet
# Joining point found at index 135 in file regularSimv103OffyB_50.parquet
# Joining point found at index 152 in file regularSimv103OffyB_51.parquet
# Joining point found at index 1001 in file regularSimv103OffyB_52.parquet
# Saved merged/merged_file_1.parquet (Size: 10.10 MB)
# Joining point found at index 0 in file regularSimv103OffyB_53.parquet
# Joining point found at index 555 in file regularSimv103OffyB_54.parquet
# Joining point found at index 2400 in file regularSimv103OffyB_55.parquet
# Joining point found at index 515 in file regularSimv103OffyB_56.parquet
# Joining point found at index 0 in file regularSimv103OffyB_57.parquet
# Joining point found at index 0 in file regularSimv103OffyB_58.parquet
# Joining point found at index 0 in file regularSimv103OffyB_59.parquet
# Joining point found at index 2 in file regularSimv103OffyB_6.parquet
# Joining point found at index 697 in file regularSimv103OffyB_60.parquet
# Joining point found at index 716 in file regularSimv103OffyB_61.parquet
# Joining point found at index 1326 in file regularSimv103OffyB_62.parquet
# Joining point found at index 197 in file regularSimv103OffyB_63.parquet
# Joining point found at index 1285 in file regularSimv103OffyB_64.parquet
# Joining point found at index 150 in file regularSimv103OffyB_65.parquet
# Joining point found at index 2570 in file regularSimv103OffyB_66.parquet
# Joining point found at index 685 in file regularSimv103OffyB_67.parquet
# Joining point found at index 4 in file regularSimv103OffyB_68.parquet
# Joining point found at index 836 in file regularSimv103OffyB_69.parquet
# Joining point found at index 114 in file regularSimv103OffyB_7.parquet
# Joining point found at index 340 in file regularSimv103OffyB_70.parquet
# Joining point found at index 0 in file regularSimv103OffyB_71.parquet
# Joining point found at index 663 in file regularSimv103OffyB_72.parquet
# Joining point found at index 0 in file regularSimv103OffyB_73.parquet
# Joining point found at index 67 in file regularSimv103OffyB_74.parquet
# Joining point found at index 0 in file regularSimv103OffyB_75.parquet
# Joining point found at index 0 in file regularSimv103OffyB_76.parquet
# Joining point found at index 57 in file regularSimv103OffyB_77.parquet
# Joining point found at index 23 in file regularSimv103OffyB_78.parquet
# Joining point found at index 334 in file regularSimv103OffyB_79.parquet
# Joining point found at index 634 in file regularSimv103OffyB_8.parquet
# Joining point found at index 59 in file regularSimv103OffyB_80.parquet
# Joining point found at index 3329 in file regularSimv103OffyB_81.parquet
# Joining point found at index 7 in file regularSimv103OffyB_9.parquet
# Saved merged/merged_file_2.parquet (Size: 7.56 MB)
# Merging complete!
