# %% [markdown]
# # Ethos
# This is actually quite a fancy file concatenator, because in fact it merges, but makes sure the stat or the end of one file is similar to the state of the start of the next so that you have continuity.  It expects "Sam-style" files.

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

def merge_parquet_files(input_folder, output_folder, size_limit_mb=2, min_length_mb=1, match_up=True):
    Path(output_folder).mkdir(parents=True, exist_ok=True)

    current_df = None
    file_counter = 1
    current_size_mb = 0
    saved_files = []
    last_time = 0
    dt = None
    last_channel = None

    parquet_files = sorted([f for f in os.listdir(input_folder) if f.endswith('.parquet')])

    for file in parquet_files:
        file_path = os.path.join(input_folder, file)
        df = pd.read_parquet(file_path)

        # Ensure the Time and Channels columns exist
        if "Time" not in df.columns or "Channels" not in df.columns:
            raise ValueError(f"Time or Channels column not found in file {file}")

        # Calculate dt if not already set
        if dt is None:
            dt = round(df["Time"].diff().mean(), 3)
            print(f"Calculated dt: {dt}")
        if match_up:
            # Optionally find the correct joining point
            if last_channel is not None:
                joining_index = df.index[df['Channels'] == last_channel].tolist()
                if joining_index:
                    joining_index = joining_index[0]
                    print(f"Joining point found at index {joining_index} in file {file}")
                    df = df.iloc[joining_index:]
                else:
                    print(f"Warning: No matching Channels value found in file {file}")

        # Adjust time to be continuous
        if current_df is not None:
            time_shift = last_time + dt - df["Time"].iloc[0]
            df["Time"] += time_shift

        if current_df is None:
            current_df = df
        else:
            current_df = pd.concat([current_df, df], ignore_index=True)

        last_time = current_df["Time"].iloc[-1]
        last_channel = current_df["Channels"].iloc[-1]

        # Check the size of the current DataFrame
        current_size_mb = current_df.memory_usage(deep=True).sum() / 1024 / 1024

        # If size limit is reached, save the current DataFrame and start a new one
        if current_size_mb >= size_limit_mb:
            output_file = os.path.join(output_folder, f'merged_file_{file_counter}.parquet')
            current_df.to_parquet(output_file, index=False)
            print(f"Saved {output_file} (Size: {current_size_mb:.2f} MB)")
            
            saved_files.append((output_file, current_size_mb))
            
            # Reset for the next file, but keep the last row to ensure continuity
            current_df = current_df.iloc[[-1]]
            file_counter += 1
            current_size_mb = current_df.memory_usage(deep=True).sum() / 1024 / 1024

    # Handle the last file
    if current_df is not None:
        if current_size_mb < min_length_mb and len(saved_files) > 0:
            # Append to the penultimate file
            penultimate_file, penultimate_size = saved_files[-1]
            penultimate_df = pd.read_parquet(penultimate_file)
            merged_df = pd.concat([penultimate_df, current_df], ignore_index=True)
            merged_size_mb = merged_df.memory_usage(deep=True).sum() / 1024 / 1024
            
            merged_df.to_parquet(penultimate_file, index=False)
            print(f"Appended to {penultimate_file} (New size: {merged_size_mb:.2f} MB)")
        else:
            # Save as a new file
            output_file = os.path.join(output_folder, f'merged_file_{file_counter}.parquet')
            current_df.to_parquet(output_file, index=False)
            print(f"Saved {output_file} (Size: {current_size_mb:.2f} MB)")

    print("Merging complete!")

# Usage
input_folder = 'source'
output_folder = 'merged'
merge_parquet_files(input_folder, output_folder, size_limit_mb=10, min_length_mb=3, match_up=True)
# Out:
# Calculated dt: 0.01
# Joining point found at index 0 in file Moon_segment_8 (10).parquet
# Joining point found at index 47 in file Moon_segment_8 (100).parquet
# Joining point found at index 392 in file Moon_segment_8 (11).parquet
# Joining point found at index 65 in file Moon_segment_8 (12).parquet
# Saved merged/merged_file_1.parquet (Size: 11.43 MB)
# Joining point found at index 0 in file Moon_segment_8 (13).parquet
# Joining point found at index 1589 in file Moon_segment_8 (14).parquet
# Joining point found at index 815 in file Moon_segment_8 (15).parquet
# Joining point found at index 0 in file Moon_segment_8 (16).parquet
# Joining point found at index 0 in file Moon_segment_8 (17).parquet
# Saved merged/merged_file_2.parquet (Size: 11.39 MB)
# Joining point found at index 57 in file Moon_segment_8 (18).parquet
# Joining point found at index 397 in file Moon_segment_8 (19).parquet
# Joining point found at index 63 in file Moon_segment_8 (2).parquet
# Joining point found at index 0 in file Moon_segment_8 (20).parquet
# Joining point found at index 420 in file Moon_segment_8 (21).parquet
# Saved merged/merged_file_3.parquet (Size: 11.42 MB)
# Joining point found at index 1 in file Moon_segment_8 (22).parquet
# Joining point found at index 0 in file Moon_segment_8 (23).parquet
# Joining point found at index 1 in file Moon_segment_8 (24).parquet
# Joining point found at index 310 in file Moon_segment_8 (25).parquet
# Joining point found at index 277 in file Moon_segment_8 (26).parquet
# Saved merged/merged_file_4.parquet (Size: 11.43 MB)
# Joining point found at index 806 in file Moon_segment_8 (27).parquet
# Joining point found at index 0 in file Moon_segment_8 (28).parquet
# Joining point found at index 18 in file Moon_segment_8 (29).parquet
# Joining point found at index 0 in file Moon_segment_8 (3).parquet
# Joining point found at index 167 in file Moon_segment_8 (30).parquet
# Saved merged/merged_file_5.parquet (Size: 11.42 MB)
# Joining point found at index 8658 in file Moon_segment_8 (31).parquet
# Joining point found at index 447 in file Moon_segment_8 (32).parquet
# Joining point found at index 186 in file Moon_segment_8 (33).parquet
# Joining point found at index 2 in file Moon_segment_8 (34).parquet
# Joining point found at index 0 in file Moon_segment_8 (35).parquet
# Saved merged/merged_file_6.parquet (Size: 11.23 MB)
# Joining point found at index 0 in file Moon_segment_8 (36).parquet
# Joining point found at index 214 in file Moon_segment_8 (37).parquet
# Joining point found at index 0 in file Moon_segment_8 (38).parquet
# Joining point found at index 1 in file Moon_segment_8 (39).parquet
# Joining point found at index 330 in file Moon_segment_8 (4).parquet
# Saved merged/merged_file_7.parquet (Size: 11.43 MB)
# Joining point found at index 153 in file Moon_segment_8 (40).parquet
# Joining point found at index 537 in file Moon_segment_8 (41).parquet
# Joining point found at index 1248 in file Moon_segment_8 (42).parquet
# Joining point found at index 53 in file Moon_segment_8 (43).parquet
# Joining point found at index 523 in file Moon_segment_8 (44).parquet
# Saved merged/merged_file_8.parquet (Size: 11.39 MB)
# Joining point found at index 356 in file Moon_segment_8 (45).parquet
# Joining point found at index 0 in file Moon_segment_8 (46).parquet
# Joining point found at index 30 in file Moon_segment_8 (47).parquet
# Joining point found at index 96 in file Moon_segment_8 (48).parquet
# Joining point found at index 1456 in file Moon_segment_8 (49).parquet
# Saved merged/merged_file_9.parquet (Size: 11.40 MB)
# Joining point found at index 506 in file Moon_segment_8 (5).parquet
# Joining point found at index 306 in file Moon_segment_8 (50).parquet
# Joining point found at index 399 in file Moon_segment_8 (51).parquet
# Joining point found at index 171 in file Moon_segment_8 (52).parquet
# Joining point found at index 142 in file Moon_segment_8 (53).parquet
# Saved merged/merged_file_10.parquet (Size: 11.41 MB)
# Joining point found at index 0 in file Moon_segment_8 (54).parquet
# Joining point found at index 1 in file Moon_segment_8 (55).parquet
# Joining point found at index 125 in file Moon_segment_8 (56).parquet
# Joining point found at index 392 in file Moon_segment_8 (57).parquet
# Joining point found at index 669 in file Moon_segment_8 (58).parquet
# Saved merged/merged_file_11.parquet (Size: 11.42 MB)
# Joining point found at index 108 in file Moon_segment_8 (59).parquet
# Joining point found at index 316 in file Moon_segment_8 (6).parquet
# Joining point found at index 346 in file Moon_segment_8 (60).parquet
# Joining point found at index 139 in file Moon_segment_8 (61).parquet
# Joining point found at index 306 in file Moon_segment_8 (62).parquet
# Saved merged/merged_file_12.parquet (Size: 11.42 MB)
# Joining point found at index 338 in file Moon_segment_8 (63).parquet
# Joining point found at index 0 in file Moon_segment_8 (64).parquet
# Joining point found at index 0 in file Moon_segment_8 (65).parquet
# Joining point found at index 0 in file Moon_segment_8 (66).parquet
# Joining point found at index 312 in file Moon_segment_8 (67).parquet
# Saved merged/merged_file_13.parquet (Size: 11.43 MB)
# Joining point found at index 1 in file Moon_segment_8 (68).parquet
# Joining point found at index 315 in file Moon_segment_8 (69).parquet
# Joining point found at index 269 in file Moon_segment_8 (7).parquet
# Joining point found at index 0 in file Moon_segment_8 (70).parquet
# Joining point found at index 106 in file Moon_segment_8 (71).parquet
# Saved merged/merged_file_14.parquet (Size: 11.43 MB)
# Joining point found at index 86 in file Moon_segment_8 (72).parquet
# Joining point found at index 18 in file Moon_segment_8 (73).parquet
# Joining point found at index 0 in file Moon_segment_8 (74).parquet
# Joining point found at index 431 in file Moon_segment_8 (75).parquet
# Joining point found at index 2172 in file Moon_segment_8 (76).parquet
# Saved merged/merged_file_15.parquet (Size: 11.38 MB)
# Joining point found at index 609 in file Moon_segment_8 (77).parquet
# Joining point found at index 612 in file Moon_segment_8 (78).parquet
# Joining point found at index 0 in file Moon_segment_8 (79).parquet
# Joining point found at index 265 in file Moon_segment_8 (8).parquet
# Joining point found at index 2194 in file Moon_segment_8 (80).parquet
# Saved merged/merged_file_16.parquet (Size: 11.36 MB)
# Joining point found at index 427 in file Moon_segment_8 (81).parquet
# Joining point found at index 0 in file Moon_segment_8 (82).parquet
# Joining point found at index 589 in file Moon_segment_8 (83).parquet
# Joining point found at index 0 in file Moon_segment_8 (84).parquet
# Joining point found at index 0 in file Moon_segment_8 (85).parquet
# Saved merged/merged_file_17.parquet (Size: 11.42 MB)
# Joining point found at index 77 in file Moon_segment_8 (86).parquet
# Joining point found at index 310 in file Moon_segment_8 (87).parquet
# Joining point found at index 2205 in file Moon_segment_8 (88).parquet
# Joining point found at index 0 in file Moon_segment_8 (89).parquet
# Joining point found at index 34 in file Moon_segment_8 (9).parquet
# Saved merged/merged_file_18.parquet (Size: 11.38 MB)
# Joining point found at index 229 in file Moon_segment_8 (90).parquet
# Joining point found at index 805 in file Moon_segment_8 (91).parquet
# Joining point found at index 0 in file Moon_segment_8 (92).parquet
# Joining point found at index 899 in file Moon_segment_8 (93).parquet
# Joining point found at index 149 in file Moon_segment_8 (94).parquet
# Saved merged/merged_file_19.parquet (Size: 11.40 MB)
# Joining point found at index 839 in file Moon_segment_8 (95).parquet
# Joining point found at index 0 in file Moon_segment_8 (96).parquet
# Joining point found at index 60 in file Moon_segment_8 (97).parquet
# Joining point found at index 363 in file Moon_segment_8 (98).parquet
# Joining point found at index 209 in file Moon_segment_8 (99).parquet
# Saved merged/merged_file_20.parquet (Size: 11.41 MB)
# Joining point found at index 0 in file Numan_1_segment_8 (1).parquet
# Joining point found at index 224 in file Numan_1_segment_8 (10).parquet
# Joining point found at index 181 in file Numan_1_segment_8 (100).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (11).parquet
# Joining point found at index 157 in file Numan_1_segment_8 (12).parquet
# Joining point found at index 117 in file Numan_1_segment_8 (13).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (14).parquet
# Joining point found at index 216 in file Numan_1_segment_8 (15).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (16).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (17).parquet
# Joining point found at index 286 in file Numan_1_segment_8 (18).parquet
# Joining point found at index 143 in file Numan_1_segment_8 (19).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (2).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (20).parquet
# Joining point found at index 144 in file Numan_1_segment_8 (21).parquet
# Joining point found at index 571 in file Numan_1_segment_8 (22).parquet
# Joining point found at index 96 in file Numan_1_segment_8 (23).parquet
# Joining point found at index 58 in file Numan_1_segment_8 (24).parquet
# Joining point found at index 28 in file Numan_1_segment_8 (25).parquet
# Joining point found at index 1876 in file Numan_1_segment_8 (26).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (27).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (28).parquet
# Joining point found at index 74 in file Numan_1_segment_8 (29).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (3).parquet
# Joining point found at index 1190 in file Numan_1_segment_8 (30).parquet
# Joining point found at index 131 in file Numan_1_segment_8 (31).parquet
# Joining point found at index 182 in file Numan_1_segment_8 (32).parquet
# Joining point found at index 1258 in file Numan_1_segment_8 (33).parquet
# Joining point found at index 160 in file Numan_1_segment_8 (34).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (35).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (36).parquet
# Joining point found at index 176 in file Numan_1_segment_8 (37).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (38).parquet
# Joining point found at index 196 in file Numan_1_segment_8 (39).parquet
# Joining point found at index 131 in file Numan_1_segment_8 (4).parquet
# Joining point found at index 2 in file Numan_1_segment_8 (40).parquet
# Joining point found at index 446 in file Numan_1_segment_8 (41).parquet
# Joining point found at index 2245 in file Numan_1_segment_8 (42).parquet
# Joining point found at index 225 in file Numan_1_segment_8 (43).parquet
# Joining point found at index 339 in file Numan_1_segment_8 (44).parquet
# Joining point found at index 24 in file Numan_1_segment_8 (45).parquet
# Joining point found at index 109 in file Numan_1_segment_8 (46).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (47).parquet
# Joining point found at index 15 in file Numan_1_segment_8 (48).parquet
# Joining point found at index 1 in file Numan_1_segment_8 (49).parquet
# Saved merged/merged_file_21.parquet (Size: 10.05 MB)
# Joining point found at index 0 in file Numan_1_segment_8 (5).parquet
# Joining point found at index 438 in file Numan_1_segment_8 (50).parquet
# Joining point found at index 115 in file Numan_1_segment_8 (51).parquet
# Joining point found at index 146 in file Numan_1_segment_8 (52).parquet
# Joining point found at index 878 in file Numan_1_segment_8 (53).parquet
# Joining point found at index 362 in file Numan_1_segment_8 (54).parquet
# Joining point found at index 443 in file Numan_1_segment_8 (55).parquet
# Joining point found at index 174 in file Numan_1_segment_8 (56).parquet
# Joining point found at index 80 in file Numan_1_segment_8 (57).parquet
# Joining point found at index 189 in file Numan_1_segment_8 (58).parquet
# Joining point found at index 486 in file Numan_1_segment_8 (59).parquet
# Joining point found at index 301 in file Numan_1_segment_8 (6).parquet
# Joining point found at index 63 in file Numan_1_segment_8 (60).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (61).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (62).parquet
# Joining point found at index 718 in file Numan_1_segment_8 (63).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (64).parquet
# Joining point found at index 189 in file Numan_1_segment_8 (65).parquet
# Joining point found at index 349 in file Numan_1_segment_8 (66).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (67).parquet
# Joining point found at index 68 in file Numan_1_segment_8 (68).parquet
# Joining point found at index 1 in file Numan_1_segment_8 (69).parquet
# Joining point found at index 506 in file Numan_1_segment_8 (7).parquet
# Joining point found at index 371 in file Numan_1_segment_8 (70).parquet
# Joining point found at index 552 in file Numan_1_segment_8 (71).parquet
# Joining point found at index 81 in file Numan_1_segment_8 (72).parquet
# Joining point found at index 207 in file Numan_1_segment_8 (73).parquet
# Joining point found at index 35 in file Numan_1_segment_8 (74).parquet
# Joining point found at index 75 in file Numan_1_segment_8 (75).parquet
# Joining point found at index 28 in file Numan_1_segment_8 (76).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (77).parquet
# Joining point found at index 275 in file Numan_1_segment_8 (78).parquet
# Joining point found at index 31 in file Numan_1_segment_8 (79).parquet
# Joining point found at index 687 in file Numan_1_segment_8 (8).parquet
# Joining point found at index 47 in file Numan_1_segment_8 (80).parquet
# Joining point found at index 191 in file Numan_1_segment_8 (81).parquet
# Joining point found at index 36 in file Numan_1_segment_8 (82).parquet
# Joining point found at index 256 in file Numan_1_segment_8 (83).parquet
# Joining point found at index 1 in file Numan_1_segment_8 (84).parquet
# Joining point found at index 500 in file Numan_1_segment_8 (85).parquet
# Joining point found at index 187 in file Numan_1_segment_8 (86).parquet
# Joining point found at index 266 in file Numan_1_segment_8 (87).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (88).parquet
# Joining point found at index 38 in file Numan_1_segment_8 (89).parquet
# Joining point found at index 278 in file Numan_1_segment_8 (9).parquet
# Saved merged/merged_file_22.parquet (Size: 10.08 MB)
# Joining point found at index 1300 in file Numan_1_segment_8 (90).parquet
# Joining point found at index 1431 in file Numan_1_segment_8 (91).parquet
# Joining point found at index 675 in file Numan_1_segment_8 (92).parquet
# Joining point found at index 12 in file Numan_1_segment_8 (93).parquet
# Joining point found at index 524 in file Numan_1_segment_8 (94).parquet
# Joining point found at index 103 in file Numan_1_segment_8 (95).parquet
# Joining point found at index 320 in file Numan_1_segment_8 (96).parquet
# Joining point found at index 0 in file Numan_1_segment_8 (97).parquet
# Joining point found at index 2 in file Numan_1_segment_8 (98).parquet
# Joining point found at index 131 in file Numan_1_segment_8 (99).parquet
# Joining point found at index 49 in file Numan_2_segment_3 (1).parquet
# Joining point found at index 212 in file Numan_2_segment_3 (10).parquet
# Joining point found at index 887 in file Numan_2_segment_3 (100).parquet
# Joining point found at index 10 in file Numan_2_segment_3 (11).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (12).parquet
# Joining point found at index 185 in file Numan_2_segment_3 (13).parquet
# Joining point found at index 449 in file Numan_2_segment_3 (14).parquet
# Saved merged/merged_file_23.parquet (Size: 10.16 MB)
# Joining point found at index 5 in file Numan_2_segment_3 (15).parquet
# Joining point found at index 177 in file Numan_2_segment_3 (16).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (17).parquet
# Joining point found at index 11 in file Numan_2_segment_3 (18).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (19).parquet
# Joining point found at index 203 in file Numan_2_segment_3 (2).parquet
# Joining point found at index 180 in file Numan_2_segment_3 (20).parquet
# Joining point found at index 77 in file Numan_2_segment_3 (21).parquet
# Joining point found at index 247 in file Numan_2_segment_3 (22).parquet
# Saved merged/merged_file_24.parquet (Size: 10.28 MB)
# Joining point found at index 28 in file Numan_2_segment_3 (23).parquet
# Joining point found at index 467 in file Numan_2_segment_3 (24).parquet
# Joining point found at index 109 in file Numan_2_segment_3 (25).parquet
# Joining point found at index 99 in file Numan_2_segment_3 (26).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (27).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (28).parquet
# Joining point found at index 434 in file Numan_2_segment_3 (29).parquet
# Joining point found at index 89 in file Numan_2_segment_3 (3).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (30).parquet
# Saved merged/merged_file_25.parquet (Size: 10.27 MB)
# Joining point found at index 198 in file Numan_2_segment_3 (31).parquet
# Joining point found at index 174 in file Numan_2_segment_3 (32).parquet
# Joining point found at index 1290 in file Numan_2_segment_3 (33).parquet
# Joining point found at index 65 in file Numan_2_segment_3 (34).parquet
# Joining point found at index 274 in file Numan_2_segment_3 (35).parquet
# Joining point found at index 75 in file Numan_2_segment_3 (36).parquet
# Joining point found at index 292 in file Numan_2_segment_3 (37).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (38).parquet
# Joining point found at index 34 in file Numan_2_segment_3 (39).parquet
# Saved merged/merged_file_26.parquet (Size: 10.24 MB)
# Joining point found at index 430 in file Numan_2_segment_3 (4).parquet
# Joining point found at index 378 in file Numan_2_segment_3 (40).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (41).parquet
# Joining point found at index 25 in file Numan_2_segment_3 (42).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (43).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (44).parquet
# Joining point found at index 32 in file Numan_2_segment_3 (45).parquet
# Joining point found at index 574 in file Numan_2_segment_3 (46).parquet
# Joining point found at index 296 in file Numan_2_segment_3 (47).parquet
# Saved merged/merged_file_27.parquet (Size: 10.26 MB)
# Joining point found at index 555 in file Numan_2_segment_3 (48).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (49).parquet
# Joining point found at index 101 in file Numan_2_segment_3 (5).parquet
# Joining point found at index 403 in file Numan_2_segment_3 (50).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (51).parquet
# Joining point found at index 162 in file Numan_2_segment_3 (52).parquet
# Joining point found at index 329 in file Numan_2_segment_3 (53).parquet
# Joining point found at index 873 in file Numan_2_segment_3 (54).parquet
# Joining point found at index 434 in file Numan_2_segment_3 (55).parquet
# Saved merged/merged_file_28.parquet (Size: 10.23 MB)
# Joining point found at index 108 in file Numan_2_segment_3 (56).parquet
# Joining point found at index 1 in file Numan_2_segment_3 (57).parquet
# Joining point found at index 346 in file Numan_2_segment_3 (58).parquet
# Joining point found at index 1580 in file Numan_2_segment_3 (59).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (6).parquet
# Joining point found at index 2528 in file Numan_2_segment_3 (60).parquet
# Joining point found at index 453 in file Numan_2_segment_3 (61).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (62).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (63).parquet
# Saved merged/merged_file_29.parquet (Size: 10.19 MB)
# Joining point found at index 302 in file Numan_2_segment_3 (64).parquet
# Joining point found at index 275 in file Numan_2_segment_3 (65).parquet
# Joining point found at index 538 in file Numan_2_segment_3 (66).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (67).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (68).parquet
# Joining point found at index 156 in file Numan_2_segment_3 (69).parquet
# Joining point found at index 250 in file Numan_2_segment_3 (7).parquet
# Joining point found at index 505 in file Numan_2_segment_3 (70).parquet
# Joining point found at index 187 in file Numan_2_segment_3 (71).parquet
# Saved merged/merged_file_30.parquet (Size: 10.25 MB)
# Joining point found at index 365 in file Numan_2_segment_3 (72).parquet
# Joining point found at index 797 in file Numan_2_segment_3 (73).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (74).parquet
# Joining point found at index 237 in file Numan_2_segment_3 (75).parquet
# Joining point found at index 2087 in file Numan_2_segment_3 (76).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (77).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (78).parquet
# Joining point found at index 372 in file Numan_2_segment_3 (79).parquet
# Joining point found at index 139 in file Numan_2_segment_3 (8).parquet
# Saved merged/merged_file_31.parquet (Size: 10.21 MB)
# Joining point found at index 8 in file Numan_2_segment_3 (80).parquet
# Joining point found at index 417 in file Numan_2_segment_3 (81).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (82).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (83).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (84).parquet
# Joining point found at index 66 in file Numan_2_segment_3 (85).parquet
# Joining point found at index 87 in file Numan_2_segment_3 (86).parquet
# Joining point found at index 341 in file Numan_2_segment_3 (87).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (88).parquet
# Saved merged/merged_file_32.parquet (Size: 10.28 MB)
# Joining point found at index 71 in file Numan_2_segment_3 (89).parquet
# Joining point found at index 100 in file Numan_2_segment_3 (9).parquet
# Joining point found at index 185 in file Numan_2_segment_3 (90).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (91).parquet
# Joining point found at index 50 in file Numan_2_segment_3 (92).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (93).parquet
# Joining point found at index 0 in file Numan_2_segment_3 (94).parquet
# Joining point found at index 249 in file Numan_2_segment_3 (95).parquet
# Joining point found at index 252 in file Numan_2_segment_3 (96).parquet
# Saved merged/merged_file_33.parquet (Size: 10.28 MB)
# Joining point found at index 95 in file Numan_2_segment_3 (97).parquet
# Joining point found at index 757 in file Numan_2_segment_3 (98).parquet
# Joining point found at index 100 in file Numan_2_segment_3 (99).parquet
# Saved merged/merged_file_34.parquet (Size: 3.41 MB)
# Merging complete!
