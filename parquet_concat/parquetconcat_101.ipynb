# %% [markdown]
# # Ethos
# This is actually quite a fancy file concatenator, because in fact it merges, but makes sure the stat or the end of one file is similar to the state of the start of the next so that you have continuity.  It expects "Sam-style" files.

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

def merge_parquet_files(input_folder, output_folder, size_limit_mb=2, min_length_mb=1, match_up=True):
    Path(output_folder).mkdir(parents=True, exist_ok=True)

    current_df = None
    file_counter = 1
    current_size_mb = 0
    saved_files = []
    last_time = 0
    dt = None
    last_channel = None

    parquet_files = sorted([f for f in os.listdir(input_folder) if f.endswith('.parquet')])

    for file in parquet_files:
        file_path = os.path.join(input_folder, file)
        df = pd.read_parquet(file_path)

        # Ensure the Time and Channels columns exist
        if "Time" not in df.columns or "Channels" not in df.columns:
            raise ValueError(f"Time or Channels column not found in file {file}")

        # Calculate dt if not already set
        if dt is None:
            dt = round(df["Time"].diff().mean(), 3)
            print(f"Calculated dt: {dt}")
        if match_up:
            # Optionally find the correct joining point
            if last_channel is not None:
                joining_index = df.index[df['Channels'] == last_channel].tolist()
                if joining_index:
                    joining_index = joining_index[0]
                    print(f"Joining point found at index {joining_index} in file {file}")
                    df = df.iloc[joining_index:]
                else:
                    print(f"Warning: No matching Channels value found in file {file}")

        # Adjust time to be continuous
        if current_df is not None:
            time_shift = last_time + dt - df["Time"].iloc[0]
            df["Time"] += time_shift

        if current_df is None:
            current_df = df
        else:
            current_df = pd.concat([current_df, df], ignore_index=True)

        last_time = current_df["Time"].iloc[-1]
        last_channel = current_df["Channels"].iloc[-1]

        # Check the size of the current DataFrame
        current_size_mb = current_df.memory_usage(deep=True).sum() / 1024 / 1024

        # If size limit is reached, save the current DataFrame and start a new one
        if current_size_mb >= size_limit_mb:
            output_file = os.path.join(output_folder, f'merged_file_{file_counter}.parquet')
            current_df.to_parquet(output_file, index=False)
            print(f"Saved {output_file} (Size: {current_size_mb:.2f} MB)")
            
            saved_files.append((output_file, current_size_mb))
            
            # Reset for the next file, but keep the last row to ensure continuity
            current_df = current_df.iloc[[-1]]
            file_counter += 1
            current_size_mb = current_df.memory_usage(deep=True).sum() / 1024 / 1024

    # Handle the last file
    if current_df is not None:
        if current_size_mb < min_length_mb and len(saved_files) > 0:
            # Append to the penultimate file
            penultimate_file, penultimate_size = saved_files[-1]
            penultimate_df = pd.read_parquet(penultimate_file)
            merged_df = pd.concat([penultimate_df, current_df], ignore_index=True)
            merged_size_mb = merged_df.memory_usage(deep=True).sum() / 1024 / 1024
            
            merged_df.to_parquet(penultimate_file, index=False)
            print(f"Appended to {penultimate_file} (New size: {merged_size_mb:.2f} MB)")
        else:
            # Save as a new file
            output_file = os.path.join(output_folder, f'merged_file_{file_counter}.parquet')
            current_df.to_parquet(output_file, index=False)
            print(f"Saved {output_file} (Size: {current_size_mb:.2f} MB)")

    print("Merging complete!")

# Usage
input_folder = 'source'
output_folder = 'merged'
merge_parquet_files(input_folder, output_folder, size_limit_mb=10, min_length_mb=3, match_up=True)
# Out:
# Calculated dt: 0.1
# Joining point found at index 201 in file regularSimv103OffyB_101.parquet
# Joining point found at index 0 in file regularSimv103OffyB_102.parquet
# Joining point found at index 0 in file regularSimv103OffyB_103.parquet
# Joining point found at index 0 in file regularSimv103OffyB_104.parquet
# Joining point found at index 1 in file regularSimv103OffyB_105.parquet
# Joining point found at index 0 in file regularSimv103OffyB_106.parquet
# Joining point found at index 930 in file regularSimv103OffyB_107.parquet
# Joining point found at index 597 in file regularSimv103OffyB_108.parquet
# Saved merged/merged_file_1.parquet (Size: 10.26 MB)
# Joining point found at index 1 in file regularSimv103OffyB_109.parquet
# Joining point found at index 4182 in file regularSimv103OffyB_110.parquet
# Joining point found at index 632 in file regularSimv103OffyB_111.parquet
# Joining point found at index 1107 in file regularSimv103OffyB_112.parquet
# Joining point found at index 173 in file regularSimv103OffyB_113.parquet
# Joining point found at index 102 in file regularSimv103OffyB_114.parquet
# Joining point found at index 0 in file regularSimv103OffyB_115.parquet
# Joining point found at index 1186 in file regularSimv103OffyB_116.parquet
# Joining point found at index 1 in file regularSimv103OffyB_117.parquet
# Saved merged/merged_file_2.parquet (Size: 10.13 MB)
# Joining point found at index 566 in file regularSimv103OffyB_118.parquet
# Joining point found at index 5948 in file regularSimv103OffyB_119.parquet
# Joining point found at index 0 in file regularSimv103OffyB_120.parquet
# Joining point found at index 0 in file regularSimv103OffyB_121.parquet
# Joining point found at index 0 in file regularSimv103OffyB_122.parquet
# Joining point found at index 0 in file regularSimv103OffyB_123.parquet
# Joining point found at index 235 in file regularSimv103OffyB_124.parquet
# Joining point found at index 208 in file regularSimv103OffyB_125.parquet
# Joining point found at index 3588 in file regularSimv103OffyB_126.parquet
# Saved merged/merged_file_3.parquet (Size: 10.06 MB)
# Joining point found at index 5712 in file regularSimv103OffyB_127.parquet
# Joining point found at index 1618 in file regularSimv103OffyB_128.parquet
# Joining point found at index 2051 in file regularSimv103OffyB_129.parquet
# Joining point found at index 7915 in file regularSimv103OffyB_130.parquet
# Joining point found at index 2618 in file regularSimv103OffyB_131.parquet
# Joining point found at index 1 in file regularSimv103OffyB_132.parquet
# Joining point found at index 296 in file regularSimv103OffyB_133.parquet
# Joining point found at index 0 in file regularSimv103OffyB_134.parquet
# Joining point found at index 186 in file regularSimv103OffyB_135.parquet
# Joining point found at index 3774 in file regularSimv103OffyB_136.parquet
# Saved merged/merged_file_4.parquet (Size: 10.89 MB)
# Joining point found at index 894 in file regularSimv103OffyB_137.parquet
# Joining point found at index 1660 in file regularSimv103OffyB_138.parquet
# Joining point found at index 312 in file regularSimv103OffyB_139.parquet
# Joining point found at index 1722 in file regularSimv103OffyB_140.parquet
# Joining point found at index 0 in file regularSimv103OffyB_141.parquet
# Joining point found at index 0 in file regularSimv103OffyB_142.parquet
# Joining point found at index 0 in file regularSimv103OffyB_143.parquet
# Joining point found at index 0 in file regularSimv103OffyB_144.parquet
# Joining point found at index 0 in file regularSimv103OffyB_145.parquet
# Saved merged/merged_file_5.parquet (Size: 10.19 MB)
# Joining point found at index 591 in file regularSimv103OffyB_146.parquet
# Joining point found at index 4063 in file regularSimv103OffyB_147.parquet
# Joining point found at index 0 in file regularSimv103OffyB_148.parquet
# Joining point found at index 0 in file regularSimv103OffyB_149.parquet
# Joining point found at index 0 in file regularSimv103OffyB_150.parquet
# Joining point found at index 0 in file regularSimv103OffyB_151.parquet
# Joining point found at index 0 in file regularSimv103OffyB_152.parquet
# Joining point found at index 519 in file regularSimv103OffyB_153.parquet
# Joining point found at index 159 in file regularSimv103OffyB_154.parquet
# Saved merged/merged_file_6.parquet (Size: 10.18 MB)
# Joining point found at index 742 in file regularSimv103OffyB_155.parquet
# Joining point found at index 0 in file regularSimv103OffyB_156.parquet
# Joining point found at index 0 in file regularSimv103OffyB_157.parquet
# Joining point found at index 0 in file regularSimv103OffyB_158.parquet
# Joining point found at index 80 in file regularSimv103OffyB_159.parquet
# Joining point found at index 0 in file regularSimv103OffyB_160.parquet
# Joining point found at index 10 in file regularSimv103OffyB_161.parquet
# Joining point found at index 977 in file regularSimv103OffyB_162.parquet
# Joining point found at index 231 in file regularSimv103OffyB_163.parquet
# Saved merged/merged_file_7.parquet (Size: 10.25 MB)
# Joining point found at index 678 in file regularSimv103OffyB_164.parquet
# Joining point found at index 0 in file regularSimv103OffyB_165.parquet
# Joining point found at index 1789 in file regularSimv103OffyB_166.parquet
# Joining point found at index 136 in file regularSimv103OffyB_167.parquet
# Joining point found at index 470 in file regularSimv103OffyB_168.parquet
# Joining point found at index 340 in file regularSimv103OffyB_169.parquet
# Joining point found at index 29 in file regularSimv103OffyB_170.parquet
# Joining point found at index 216 in file regularSimv103OffyB_171.parquet
# Joining point found at index 1414 in file regularSimv103OffyB_172.parquet
# Saved merged/merged_file_8.parquet (Size: 10.18 MB)
# Joining point found at index 730 in file regularSimv103OffyB_173.parquet
# Joining point found at index 1580 in file regularSimv103OffyB_174.parquet
# Joining point found at index 1 in file regularSimv103OffyB_175.parquet
# Joining point found at index 140 in file regularSimv103OffyB_176.parquet
# Joining point found at index 30 in file regularSimv103OffyB_177.parquet
# Joining point found at index 1 in file regularSimv103OffyB_178.parquet
# Joining point found at index 208 in file regularSimv103OffyB_179.parquet
# Joining point found at index 786 in file regularSimv103OffyB_180.parquet
# Joining point found at index 732 in file regularSimv103OffyB_181.parquet
# Saved merged/merged_file_9.parquet (Size: 10.20 MB)
# Joining point found at index 1780 in file regularSimv103OffyB_182.parquet
# Joining point found at index 262 in file regularSimv103OffyB_183.parquet
# Joining point found at index 264 in file regularSimv103OffyB_184.parquet
# Joining point found at index 304 in file regularSimv103OffyB_185.parquet
# Joining point found at index 0 in file regularSimv103OffyB_186.parquet
# Joining point found at index 121 in file regularSimv103OffyB_187.parquet
# Joining point found at index 861 in file regularSimv103OffyB_188.parquet
# Joining point found at index 1042 in file regularSimv103OffyB_189.parquet
# Joining point found at index 1325 in file regularSimv103OffyB_190.parquet
# Saved merged/merged_file_10.parquet (Size: 10.16 MB)
# Joining point found at index 1962 in file regularSimv103OffyB_191.parquet
# Joining point found at index 0 in file regularSimv103OffyB_192.parquet
# Joining point found at index 443 in file regularSimv103OffyB_193.parquet
# Joining point found at index 0 in file regularSimv103OffyB_194.parquet
# Joining point found at index 1 in file regularSimv103OffyB_195.parquet
# Joining point found at index 0 in file regularSimv103OffyB_196.parquet
# Joining point found at index 0 in file regularSimv103OffyB_197.parquet
# Joining point found at index 1827 in file regularSimv103OffyB_198.parquet
# Joining point found at index 98 in file regularSimv103OffyB_199.parquet
# Saved merged/merged_file_11.parquet (Size: 10.20 MB)
# Joining point found at index 3198 in file regularSimv103OffyB_200.parquet
# Joining point found at index 3415 in file regularSimv103OffyB_201.parquet
# Joining point found at index 1242 in file regularSimv103OffyB_202.parquet
# Joining point found at index 2666 in file regularSimv103OffyB_203.parquet
# Joining point found at index 2074 in file regularSimv103OffyB_204.parquet
# Joining point found at index 2024 in file regularSimv103OffyB_205.parquet
# Joining point found at index 6241 in file regularSimv103OffyB_206.parquet
# Joining point found at index 0 in file regularSimv103OffyB_207.parquet
# Joining point found at index 879 in file regularSimv103OffyB_208.parquet
# Joining point found at index 340 in file regularSimv103OffyB_209.parquet
# Saved merged/merged_file_12.parquet (Size: 10.94 MB)
# Joining point found at index 1 in file regularSimv103OffyB_210.parquet
# Joining point found at index 0 in file regularSimv103OffyB_211.parquet
# Joining point found at index 8 in file regularSimv103OffyB_212.parquet
# Joining point found at index 0 in file regularSimv103OffyB_213.parquet
# Joining point found at index 2810 in file regularSimv103OffyB_214.parquet
# Joining point found at index 399 in file regularSimv103OffyB_215.parquet
# Joining point found at index 290 in file regularSimv103OffyB_216.parquet
# Joining point found at index 510 in file regularSimv103OffyB_217.parquet
# Joining point found at index 0 in file regularSimv103OffyB_218.parquet
# Saved merged/merged_file_13.parquet (Size: 10.21 MB)
# Joining point found at index 0 in file regularSimv103OffyB_219.parquet
# Joining point found at index 1 in file regularSimv103OffyB_220.parquet
# Joining point found at index 980 in file regularSimv103OffyB_221.parquet
# Joining point found at index 1045 in file regularSimv103OffyB_222.parquet
# Joining point found at index 3 in file regularSimv103OffyB_223.parquet
# Joining point found at index 895 in file regularSimv103OffyB_224.parquet
# Joining point found at index 155 in file regularSimv103OffyB_225.parquet
# Joining point found at index 0 in file regularSimv103OffyB_226.parquet
# Joining point found at index 580 in file regularSimv103OffyB_227.parquet
# Saved merged/merged_file_14.parquet (Size: 10.22 MB)
# Joining point found at index 423 in file regularSimv103OffyB_228.parquet
# Joining point found at index 2962 in file regularSimv103OffyB_229.parquet
# Joining point found at index 686 in file regularSimv103OffyB_230.parquet
# Joining point found at index 148 in file regularSimv103OffyB_231.parquet
# Joining point found at index 185 in file regularSimv103OffyB_232.parquet
# Joining point found at index 0 in file regularSimv103OffyB_233.parquet
# Joining point found at index 854 in file regularSimv103OffyB_234.parquet
# Joining point found at index 0 in file regularSimv103OffyB_235.parquet
# Joining point found at index 913 in file regularSimv103OffyB_236.parquet
# Saved merged/merged_file_15.parquet (Size: 10.16 MB)
# Joining point found at index 4150 in file regularSimv103OffyB_237.parquet
# Joining point found at index 0 in file regularSimv103OffyB_238.parquet
# Joining point found at index 0 in file regularSimv103OffyB_239.parquet
# Joining point found at index 0 in file regularSimv103OffyB_240.parquet
# Joining point found at index 0 in file regularSimv103OffyB_241.parquet
# Joining point found at index 0 in file regularSimv103OffyB_242.parquet
# Joining point found at index 351 in file regularSimv103OffyB_243.parquet
# Joining point found at index 0 in file regularSimv103OffyB_244.parquet
# Joining point found at index 0 in file regularSimv103OffyB_245.parquet
# Saved merged/merged_file_16.parquet (Size: 10.20 MB)
# Joining point found at index 1207 in file regularSimv103OffyB_246.parquet
# Joining point found at index 235 in file regularSimv103OffyB_247.parquet
# Joining point found at index 439 in file regularSimv103OffyB_248.parquet
# Joining point found at index 124 in file regularSimv103OffyB_249.parquet
# Joining point found at index 119 in file regularSimv103OffyB_250.parquet
# Joining point found at index 1572 in file regularSimv103OffyB_251.parquet
# Joining point found at index 0 in file regularSimv103OffyB_252.parquet
# Joining point found at index 4747 in file regularSimv103OffyB_253.parquet
# Joining point found at index 332 in file regularSimv103OffyB_254.parquet
# Saved merged/merged_file_17.parquet (Size: 10.10 MB)
# Joining point found at index 9235 in file regularSimv103OffyB_255.parquet
# Joining point found at index 299 in file regularSimv103OffyB_256.parquet
# Joining point found at index 0 in file regularSimv103OffyB_257.parquet
# Joining point found at index 0 in file regularSimv103OffyB_258.parquet
# Joining point found at index 0 in file regularSimv103OffyB_259.parquet
# Joining point found at index 0 in file regularSimv103OffyB_260.parquet
# Joining point found at index 4338 in file regularSimv103OffyB_261.parquet
# Joining point found at index 1012 in file regularSimv103OffyB_262.parquet
# Joining point found at index 0 in file regularSimv103OffyB_263.parquet
# Joining point found at index 159 in file regularSimv103OffyB_264.parquet
# Saved merged/merged_file_18.parquet (Size: 11.10 MB)
# Joining point found at index 0 in file regularSimv103OffyB_265.parquet
# Joining point found at index 1559 in file regularSimv103OffyB_266.parquet
# Joining point found at index 907 in file regularSimv103OffyB_267.parquet
# Joining point found at index 4 in file regularSimv103OffyB_268.parquet
# Joining point found at index 1 in file regularSimv103OffyB_269.parquet
# Joining point found at index 0 in file regularSimv103OffyB_270.parquet
# Joining point found at index 0 in file regularSimv103OffyB_271.parquet
# Joining point found at index 1068 in file regularSimv103OffyB_272.parquet
# Joining point found at index 1 in file regularSimv103OffyB_273.parquet
# Saved merged/merged_file_19.parquet (Size: 10.22 MB)
# Joining point found at index 1158 in file regularSimv103OffyB_274.parquet
# Joining point found at index 1558 in file regularSimv103OffyB_275.parquet
# Joining point found at index 2817 in file regularSimv103OffyB_276.parquet
# Joining point found at index 0 in file regularSimv103OffyB_277.parquet
# Joining point found at index 0 in file regularSimv103OffyB_278.parquet
# Joining point found at index 2757 in file regularSimv103OffyB_279.parquet
# Joining point found at index 10 in file regularSimv103OffyB_280.parquet
# Joining point found at index 14 in file regularSimv103OffyB_281.parquet
# Joining point found at index 152 in file regularSimv103OffyB_282.parquet
# Saved merged/merged_file_20.parquet (Size: 10.11 MB)
# Joining point found at index 635 in file regularSimv103OffyB_283.parquet
# Joining point found at index 0 in file regularSimv103OffyB_284.parquet
# Joining point found at index 0 in file regularSimv103OffyB_285.parquet
# Joining point found at index 412 in file regularSimv103OffyB_286.parquet
# Joining point found at index 95 in file regularSimv103OffyB_287.parquet
# Joining point found at index 1447 in file regularSimv103OffyB_288.parquet
# Joining point found at index 0 in file regularSimv103OffyB_289.parquet
# Joining point found at index 0 in file regularSimv103OffyB_290.parquet
# Joining point found at index 0 in file regularSimv103OffyB_291.parquet
# Saved merged/merged_file_21.parquet (Size: 10.24 MB)
# Joining point found at index 0 in file regularSimv103OffyB_292.parquet
# Joining point found at index 0 in file regularSimv103OffyB_293.parquet
# Joining point found at index 2594 in file regularSimv103OffyB_294.parquet
# Joining point found at index 1122 in file regularSimv103OffyB_295.parquet
# Joining point found at index 2907 in file regularSimv103OffyB_296.parquet
# Joining point found at index 1431 in file regularSimv103OffyB_297.parquet
# Joining point found at index 0 in file regularSimv103OffyB_298.parquet
# Joining point found at index 859 in file regularSimv103OffyB_299.parquet
# Joining point found at index 10 in file regularSimv103OffyB_300.parquet
# Saved merged/merged_file_22.parquet (Size: 10.10 MB)
# Joining point found at index 0 in file regularSimv103OffyB_301.parquet
# Joining point found at index 2645 in file regularSimv103OffyB_302.parquet
# Joining point found at index 102 in file regularSimv103OffyB_303.parquet
# Joining point found at index 1 in file regularSimv103OffyB_304.parquet
# Joining point found at index 174 in file regularSimv103OffyB_305.parquet
# Joining point found at index 815 in file regularSimv103OffyB_306.parquet
# Joining point found at index 0 in file regularSimv103OffyB_307.parquet
# Joining point found at index 97 in file regularSimv103OffyB_308.parquet
# Joining point found at index 0 in file regularSimv103OffyB_309.parquet
# Saved merged/merged_file_23.parquet (Size: 10.21 MB)
# Joining point found at index 0 in file regularSimv103OffyB_310.parquet
# Joining point found at index 526 in file regularSimv103OffyB_311.parquet
# Joining point found at index 1067 in file regularSimv103OffyB_312.parquet
# Joining point found at index 133 in file regularSimv103OffyB_313.parquet
# Joining point found at index 0 in file regularSimv103OffyB_314.parquet
# Joining point found at index 690 in file regularSimv103OffyB_315.parquet
# Joining point found at index 403 in file regularSimv103OffyB_316.parquet
# Joining point found at index 41 in file regularSimv103OffyB_317.parquet
# Joining point found at index 1146 in file regularSimv103OffyB_318.parquet
# Saved merged/merged_file_24.parquet (Size: 10.21 MB)
# Joining point found at index 230 in file regularSimv103OffyB_319.parquet
# Joining point found at index 3288 in file regularSimv103OffyB_320.parquet
# Joining point found at index 0 in file regularSimv103OffyB_321.parquet
# Joining point found at index 61 in file regularSimv103OffyB_82.parquet
# Joining point found at index 1 in file regularSimv103OffyB_83.parquet
# Joining point found at index 141 in file regularSimv103OffyB_84.parquet
# Joining point found at index 0 in file regularSimv103OffyB_85.parquet
# Joining point found at index 0 in file regularSimv103OffyB_86.parquet
# Joining point found at index 0 in file regularSimv103OffyB_87.parquet
# Saved merged/merged_file_25.parquet (Size: 10.21 MB)
# Joining point found at index 0 in file regularSimv103OffyB_88.parquet
# Joining point found at index 71 in file regularSimv103OffyB_89.parquet
# Joining point found at index 0 in file regularSimv103OffyB_90.parquet
# Joining point found at index 135 in file regularSimv103OffyB_91.parquet
# Joining point found at index 103 in file regularSimv103OffyB_92.parquet
# Joining point found at index 0 in file regularSimv103OffyB_93.parquet
# Joining point found at index 1 in file regularSimv103OffyB_94.parquet
# Joining point found at index 0 in file regularSimv103OffyB_95.parquet
# Joining point found at index 806 in file regularSimv103OffyB_96.parquet
# Saved merged/merged_file_26.parquet (Size: 10.27 MB)
# Joining point found at index 0 in file regularSimv103OffyB_97.parquet
# Joining point found at index 229 in file regularSimv103OffyB_98.parquet
# Joining point found at index 2304 in file regularSimv103OffyB_99.parquet
# Saved merged/merged_file_27.parquet (Size: 3.38 MB)
# Merging complete!
